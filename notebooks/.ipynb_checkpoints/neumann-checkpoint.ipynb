# %% [markdown]
# # Test finding conserved quantities in Neumann model

# %%
import numpy as np
import tensorflow as tf
import sys
sys.path.append("../")
import os

from models import *
from hamiltonians import parameterized_neumann
from utils import make_train_op
from losses import make_loss
from data import make_data
from utils import visualize_chain_bijector, is_symplectic

DTYPE=tf.float32
NP_DTYPE=np.float32
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-0cad2b489487> in <module>
#       9 from utils import make_train_op
#      10 from losses import make_loss
# ---> 11 from data import make_data
#      12 from utils import visualize_chain_bijector, is_symplectic
#      13
#
# ~/GitHub/CanonicalFlows/data.py in <module>
#       1 import tensorflow as tf
#       2 from functools import reduce
# ----> 3 import tensorflow_probability as tfp
#       4 tfd = tfp.distributions
#       5 import numpy as np
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow_probability/__init__.py in <module>
#      66
#      67
# ---> 68 _ensure_tf_install()
#      69
#      70
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow_probability/__init__.py in _ensure_tf_install()
#      63         "Please upgrade TensorFlow to proceed.".format(
#      64             required=required_tensorflow_version,
# ---> 65             present=tf.__version__))
#      66
#      67
#
# ImportError: This version of TensorFlow Probability requires TensorFlow version >= 1.13.1; Detected an installation of version 1.12.0. Please upgrade TensorFlow to proceed.

# %%
tf.set_random_seed(0)

# %%
sess = tf.InteractiveSession()

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Settings

# %%
frequencies = [.1, .2, .3]
settings = {
    'frequencies': frequencies,
    'hamiltonian': parameterized_neumann(frequencies),
    'd': 3,                    # space dimension
    'num_particles': 1,        # number of particles
    'minibatch_size': 2**7,    # Mini batch size
    'dataset_size': 2**13,      # Set to float("inf") for keeping sampling.
    'num_stacks_bijectors': 4, # Number of bijectors
    'log_dir' : "/tmp/log/im_tests/neumann-3",
    'ckpt_freq': 1000,
    'train_iters': 2,
    'visualize': True,
    'starter_learning_rate': 0.00001,    
    'decay_lr': "piecewise",
    'boundaries': [20000, 200000], # for piecewise decay
    'values': [1e-5, 1e-6, 1e-6],  # for piecewise decay
    'min_learning_rate': 1e-6,   
#     'decay_steps': 25000,  # ignored if decay_lr False
#     'decay_rate': 0.5,     # ignored if decay_lr False (decayed_learning_rate = learning_rate *
#                            #                            decay_rate ^ (global_step / decay_steps))
    'loss': "dKdphi",
    'base_dist': "action_dirac_angle",
#    'value_actions': [0.1324, 0.0312, 0.2925],
#    'elastic_net_coeff': 1.
    }
# Choose a batch of actions: needs to be divisor of dataset_size or minibatch_size if infinite dataset
r = np.random.RandomState(seed=0)
num_samples_actions = 2 # number of distinct actions (Liouville torii)
sh = (num_samples_actions, settings['d'], settings['num_particles'], 1)
settings['value_actions'] = r.rand(*sh).astype(NP_DTYPE)
print(settings['value_actions'])
# Out:
# [[[[0.5488135 ]]
#
#   [[0.71518934]]
#
#   [[0.60276335]]]
#
#
#  [[[0.5448832 ]]
#
#   [[0.4236548 ]]
#
#   [[0.6458941 ]]]]

# %% [markdown]
# Define the model T as sequence of symplectic transformations

# %%
# To account for periodicity start with oscillator flow
stack = [OscillatorFlow()] 
for i in range(settings['num_stacks_bijectors']):
    stack.extend([ZeroCenter(),
                  LinearSymplecticTwoByTwo(),
                  SymplecticAdditiveCoupling(shift_model=IrrotationalMLP())])
                  #SymplecticAdditiveCoupling(shift_model=MLP())])
T = Chain(stack)

# %% [markdown]
# Data, loss and train op:

# %%
step = tf.get_variable("global_step", [], tf.int64, tf.zeros_initializer(), trainable=False)

z = make_data(settings, sess)

loss = make_loss(settings, T, z)

train_op = make_train_op(settings, loss, step)
# Out:
# WARNING:tensorflow:From /Users/roby/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# In DiracDistribution constructor: actions =  [[[[0.5488135 ]]
#
#   [[0.71518934]]
#
#   [[0.60276335]]]
#
#
#  [[[0.5448832 ]]
#
#   [[0.4236548 ]]
#
#   [[0.6458941 ]]]]
# WARNING:tensorflow:From /Users/roby/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# Visualize before training: T is very close to identity, so circles are mapped to circles.

# %%
sess.run(tf.global_variables_initializer())

# %%
#visualize_chain_bijector(T, z, sess=sess)

# %% [markdown]
# ## Train

# %%
# Set the ZeroCenter bijectors to training mode:
for i, bijector in enumerate(T.bijectors):    
    if hasattr(bijector, 'is_training'):
        T.bijectors[i].is_training = True

# %%
tf.contrib.training.train(train_op, logdir=settings['log_dir'], save_checkpoint_secs=60)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/log/im_tests/neumann-3/model.ckpt.
# INFO:tensorflow:global_step/sec: 24.4413
# INFO:tensorflow:global_step/sec: 50.1407
# INFO:tensorflow:global_step/sec: 50.1295
# INFO:tensorflow:global_step/sec: 50.4653
# INFO:tensorflow:global_step/sec: 48.2794
# INFO:tensorflow:global_step/sec: 51.1182
# INFO:tensorflow:global_step/sec: 50.5885
# INFO:tensorflow:global_step/sec: 47.2665
# INFO:tensorflow:global_step/sec: 44.0158
# INFO:tensorflow:global_step/sec: 38.8516
# INFO:tensorflow:global_step/sec: 45.384
# INFO:tensorflow:global_step/sec: 42.141
# INFO:tensorflow:global_step/sec: 47.2287
# INFO:tensorflow:global_step/sec: 50.4003
# INFO:tensorflow:global_step/sec: 47.5815
# INFO:tensorflow:global_step/sec: 48.1441
# INFO:tensorflow:global_step/sec: 48.8087
# INFO:tensorflow:global_step/sec: 41.8571
# INFO:tensorflow:global_step/sec: 44.4549
# INFO:tensorflow:global_step/sec: 44.0762
# INFO:tensorflow:global_step/sec: 37.4793
# INFO:tensorflow:global_step/sec: 38.7362
# INFO:tensorflow:global_step/sec: 45.582
# INFO:tensorflow:global_step/sec: 43.4427
# INFO:tensorflow:global_step/sec: 43.79
# INFO:tensorflow:Saving checkpoints for 2524 into /tmp/log/im_tests/neumann-3/model.ckpt.
# INFO:tensorflow:global_step/sec: 33.835
# INFO:tensorflow:global_step/sec: 44.7466
# INFO:tensorflow:global_step/sec: 51.3225
# INFO:tensorflow:global_step/sec: 50.9558
# INFO:tensorflow:global_step/sec: 50.9478
# INFO:tensorflow:global_step/sec: 50.7811
# INFO:tensorflow:global_step/sec: 50.3701
# INFO:tensorflow:global_step/sec: 50.8564
# INFO:tensorflow:global_step/sec: 50.7733

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3534a74d2b8a> in <module>
# ----> 1 tf.contrib.training.train(train_op, logdir=settings['log_dir'], save_checkpoint_secs=60)
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/contrib/training/python/training/training.py in train(train_op, logdir, master, is_chief, scaffold, hooks, chief_only_hooks, save_checkpoint_secs, save_summaries_steps, config, max_wait_secs, run_metadata)
#     544     loss = None
#     545     while not session.should_stop():
# --> 546       loss = session.run(train_op, run_metadata=run_metadata)
#     547   return loss
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     674                           feed_dict=feed_dict,
#     675                           options=options,
# --> 676                           run_metadata=run_metadata)
#     677
#     678   def run_step_fn(self, step_fn):
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1169                               feed_dict=feed_dict,
#    1170                               options=options,
# -> 1171                               run_metadata=run_metadata)
#    1172       except _PREEMPTION_ERRORS as e:
#    1173         logging.info('An error was raised. This may be due to a preemption in '
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1253   def run(self, *args, **kwargs):
#    1254     try:
# -> 1255       return self._sess.run(*args, **kwargs)
#    1256     except _PREEMPTION_ERRORS:
#    1257       raise
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1325                                   feed_dict=feed_dict,
#    1326                                   options=options,
# -> 1327                                   run_metadata=run_metadata)
#    1328
#    1329     for hook in self._hooks:
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1089
#    1090   def run(self, *args, **kwargs):
# -> 1091     return self._sess.run(*args, **kwargs)
#    1092
#    1093   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/tensorflow_env/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test

# %%
# Load the latest parameters
saver = tf.train.Saver()
ckpt_state = tf.train.get_checkpoint_state(settings['log_dir'])
saver.restore(sess, ckpt_state.model_checkpoint_path)
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/log/im_tests/neumann-3/model.ckpt-165978

# %%
# Set the ZeroCenter bijectors to prediction mode:
for i, bijector in enumerate(T.bijectors):    
    if hasattr(bijector, 'is_training'):
        T.bijectors[i].is_training = False

# %%
# Test accuracy on new minibatch
print("Test error: ", sess.run(loss))
# Out:
# Test error:  5.085751e-06

# %%
zz = tf.expand_dims(z[0,:,:,:],0)
x = zz
for i, bijector in enumerate(T.bijectors):        
    print(i, is_symplectic( bijector, x, sess=sess, rtol=1e-06, atol=1e-06))
    x = bijector(x)
print("Full flow:")
is_symplectic( T, zz, sess=sess, rtol=1e-06, atol=1e-06 )
# Out:
# 0 True
# 1 True
# 2 True
# 3 True
# 4 True
# 5 True
# 6 True
# 7 True
# 8 True
# 9 True
# 10 True
# 11 True
# 12 True
# Full flow:
# False

# %%
visualize_chain_bijector(T, z, sess=sess)

# %% [markdown]
# ### Visualize after training - to be removed, old experiment, kept because of nice shapes...

# %%
visualize_chain_bijector(T, z, sess=sess)

# %%
plt.savefig("viz_bij_neumann_fixed_batch.png")

# %% [markdown]
# ## Look at the Learned Representation

# %% [markdown]
# Try directly integrating the eom of the transformed Hamiltonian

# %%
import matplotlib.pyplot as plt

# %%
# Use HamiltonianFlow as integrator of Hamiltonian
integrator = HamiltonianFlow(lambda z : settings['hamiltonian'](T(z)),
                             initial_t=0., 
                             final_t=10., 
                             num_steps=1000)
# 1 random initial condition (scale it back so that the motion is in the sampled region)
z0 = sess.run( tf.expand_dims(z[3,:,:,:],0) )
print(z0)
#x0 = tf.reshape([1.,0.2,1.,0.3,1.,0.4],[1,3,1,2])
# Out:
# [[[[1.8144529  0.1324    ]]
#
#   [[6.246368   0.0312    ]]
#
#   [[0.76288354 0.2925    ]]]]

# %%
traj = sess.run( integrator(z0, return_full_state=True) )
# traj has shape (time,batch,d,n,2) Here batch trivial, squeeze it out, so that time becomes batch
traj = np.squeeze(traj, 1)
phi_traj, I_traj = extract_q_p( traj )

# %% [markdown]
# Visualize: the transformed trajectories

# %%
ts = np.arange(0.,10.,.01)

plt.plot(ts, I_traj[:,0,0,0])

# %%
plt.figure(figsize=(10,10))

for d in range(settings['d']):
    for n in range(settings['num_particles']):
        plt.subplot(settings['d'], settings['num_particles'], d * settings['num_particles'] + n + 1)
        #plt.plot(qtraj[:,d,n,0], ptraj[:,d,n,0])
        plt.plot(ts, phi_traj[:,d,n,0],'r')
        plt.plot(ts, I_traj[:,d,n,0],'b')
        #plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# Looks pretty good: visually, the angles (red) evolve linearly with time, while the actions (blue) are constant

# %% [markdown]
# Trajectories of original Hamiltonian

# %%
# Use HamiltonianFlow as integrator of Hamiltonian
integrator = HamiltonianFlow(settings['hamiltonian'],
                             initial_t=0., 
                             final_t=100., 
                             num_steps=1000)
# Map to original phase space the initial point
x0 = sess.run( T(z0) )
print(x0)
# Out:
# [[[[ 0.02485632 -3.0419567 ]]
#
#   [[-0.0393815   0.76162225]]
#
#   [[ 0.04966424 -0.16638938]]]]

# %%
x0[:,:,:,1]
# Out:
# array([[[-3.0419567 ],
#         [ 0.76162225],
#         [-0.16638938]]], dtype=float32)

# %%
traj = sess.run( integrator(x0, return_full_state=True) )
# traj has shape (time,batch,d,n,2) Here batch trivial, squeeze it out, so that time becomes batch
traj = np.squeeze(traj, 1)
qtraj, ptraj = extract_q_p( traj )

# %% [markdown]
# Visualize: the transformed trajectories

# %%
plt.figure(figsize=(10,10))

for d in range(settings['d']):
    for n in range(settings['num_particles']):
        plt.subplot(settings['d'], settings['num_particles'], d * settings['num_particles'] + n + 1)
        #plt.plot(qtraj[:,d,n,0], ptraj[:,d,n,0])
        plt.plot(ts, qtraj[:,d,n,0])
        plt.plot(ts, ptraj[:,d,n,0])
        #plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# Map back to action/angle: we do not want all the way to I,phi; only till the cartesian coordinates in the action angle plane

# %%
# stop_at 1: do not run the inverse oscillator bijector which folds on upper half plane only.
ind_to_stop = 1
trans_traj = sess.run(T.inverse(tf.constant(traj), stop_at=ind_to_stop)) 
#phi_trans_traj,I_trans_traj = extract_q_p(trans_traj)

# %%
if ind_to_stop == 0:
    osc_traj = T.bijectors[0](tf.constant(trans_traj))
else:
    osc_traj = tf.constant( trans_traj )
q_osc_traj,p_osc_traj = sess.run(extract_q_p(osc_traj))

# %%
plt.figure(figsize=(10,10))

for d in range(settings['d']):
    for n in range(settings['num_particles']):
        plt.subplot(settings['d'], settings['num_particles'], d * settings['num_particles'] + n + 1)
        plt.plot(qtraj[:,d,n,0], ptraj[:,d,n,0],'r')
        plt.plot(q_osc_traj[:,d,n,0], p_osc_traj[:,d,n,0],'b')
        plt.xlim(-5, 5)
        plt.ylim(-5, 5)
        #plt.plot(ts, xtraj[:,d,n,0])
        #plt.plot(ts, ytraj[:,d,n,0])
        
        plt.gca().set_aspect('equal', adjustable='box')

# %%
dd = 2; nn = 0
plt.plot(qtraj[:,dd,nn,0], ptraj[:,dd,nn,0],'r')

# %%
plt.plot(q_osc_traj[:,dd,nn,0], p_osc_traj[:,dd,nn,0],'b')
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The circles in the transformed plane look pretty good.
